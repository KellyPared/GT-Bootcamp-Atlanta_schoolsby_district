# %%
# !pip install geopandas
# Out:
# Requirement already satisfied: geopandas in c:\users\shams_a\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: fiona>=1.8 in c:\users\shams_a\anaconda3\lib\site-packages (from geopandas) (1.9.0)
# Requirement already satisfied: pyproj>=2.6.1.post1 in c:\users\shams_a\anaconda3\lib\site-packages (from geopandas) (3.4.1)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\shams_a\anaconda3\lib\site-packages (from geopandas) (1.4.4)
# Requirement already satisfied: shapely>=1.7 in c:\users\shams_a\anaconda3\lib\site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: packaging in c:\users\shams_a\anaconda3\lib\site-packages (from geopandas) (21.3)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\shams_a\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (21.4.0)
# Requirement already satisfied: cligj>=0.5 in c:\users\shams_a\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: click~=8.0 in c:\users\shams_a\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (8.0.4)
# Requirement already satisfied: munch>=2.3.2 in c:\users\shams_a\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\shams_a\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: certifi in c:\users\shams_a\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (2022.9.14)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\shams_a\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shams_a\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\shams_a\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (1.21.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\shams_a\anaconda3\lib\site-packages (from packaging->geopandas) (3.0.9)
# Requirement already satisfied: colorama in c:\users\shams_a\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8->geopandas) (0.4.5)
# Requirement already satisfied: six in c:\users\shams_a\anaconda3\lib\site-packages (from munch>=2.3.2->fiona>=1.8->geopandas) (1.16.0)

# %%
import geopandas as gpd

# %%
# you need to change the path
atl_shp_path = r'C:\Users\shams_a\Desktop\GATECH_bootcamp\P-1\to github\datasets\ZIP_Codes\ZIP_Codes.shp'

# %%
atl_zip_shp = gpd.read_file (atl_shp_path)

# %%
atl_zip_shp.plot()
# Out:
# <AxesSubplot:>

# %%
atl_city_shp_path = r'C:\Users\shams_a\Desktop\GATECH_bootcamp\P-1\from github\gt-TAAK-group-project1\mygeodata'
atl_city_zip_shp = gpd.read_file (atl_city_shp_path)

# %%
atl_city_zip_shp.plot()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd

# %%
# you need to change the path
crime_path = r'C:\Users\shams_a\Desktop\GATECH_bootcamp\P-1\to github\zip_vs_crim.csv'

# %%
crime_zip = pd.read_csv(crime_path)

# %%
atl_zip_shp['ZIP'] = pd.to_numeric(atl_zip_shp['ZIP'])
crime_zip['zipcode'] = pd.to_numeric(crime_zip['zipcode'])

# %%
#data = pd.merge(atl_zip_shp, crime_zip, how= "left", on = ["ZIP","zipcode"])

# %%
#for i in range(0, atl_zip_shp.shape[0]):
#    for j in range(0, crime_zip.shape[0]):
#        if atl_zip_shp["ZIP"][i] == crime_zip["zipcode"][j]:
#            atl_zip_shp["crime"][i] = crime_zip["total_crime"][j]
#atl_zip_shp

# %%
atl_zip_shp.rename(columns = {'ZIP':'zipcode'}, inplace = True)
atl_zip_shp
# Out:
#      OBJECTID  zipcode                                GlobalID  last_edite  \
# 0           1    30534  {D2AC7B41-CAB3-4C88-8F0E-21CA8061DB8D}         NaN
# 1           2    30531  {0F93CBCF-F21C-4EE3-BBB9-3E1E0F1BA7D2}         NaN
# 2           3    30177  {FC6BC41B-C004-4869-80A7-01CF5D96503B}         NaN
# 3           4    30501  {F227EFE6-09F3-41CD-B47D-802D3ED7F95E}         NaN
# 4           5    30543  {F0DF9EB2-7CDC-4623-A497-29157CEB8203}         NaN
# ..        ...      ...                                     ...         ...
# 235       236    31046  {96787B44-5FC7-4285-B068-B3F69A2B20E5}         NaN
# 236       237    31830  {C5E33CA9-6048-4AC5-8C2E-24D558A85EF5}         NaN
# 237       238    31816  {073A3071-9E25-4C76-B996-0B448EA09E14}         NaN
# 238       239    30083  {DAFE42D1-C7E2-402F-B894-B2E1E5199A62}         NaN
# 239       240    30293  {70C70932-1A23-4D35-8D37-C55A7A2C65DC}         NaN
#
#                                               geometry
# 0    POLYGON ((-84.30229 34.57842, -84.30208 34.578...
# 1    POLYGON ((-83.64686 34.47594, -83.64749 34.475...
# 2    POLYGON ((-84.36438 34.41673, -84.36513 34.414...
# 3    POLYGON ((-83.88020 34.32201, -83.87727 34.325...
# 4    POLYGON ((-83.70880 34.30056, -83.70693 34.301...
# ..                                                 ...
# 235  POLYGON ((-83.81487 33.13200, -83.81535 33.131...
# 236  POLYGON ((-84.76387 32.95170, -84.76570 32.941...
# 237  POLYGON ((-84.62230 32.92431, -84.62316 32.922...
# 238  POLYGON ((-84.19451 33.83505, -84.19327 33.834...
# 239  POLYGON ((-84.71612 32.90012, -84.71393 32.906...
#
# [240 rows x 5 columns]

# %%
data = pd.merge(atl_zip_shp, crime_zip, how= "left", on = ["zipcode","zipcode"])

# %%
data
# Out:
#      OBJECTID  zipcode                                GlobalID  last_edite  \
# 0           1    30534  {D2AC7B41-CAB3-4C88-8F0E-21CA8061DB8D}         NaN
# 1           2    30531  {0F93CBCF-F21C-4EE3-BBB9-3E1E0F1BA7D2}         NaN
# 2           3    30177  {FC6BC41B-C004-4869-80A7-01CF5D96503B}         NaN
# 3           4    30501  {F227EFE6-09F3-41CD-B47D-802D3ED7F95E}         NaN
# 4           5    30543  {F0DF9EB2-7CDC-4623-A497-29157CEB8203}         NaN
# ..        ...      ...                                     ...         ...
# 235       236    31046  {96787B44-5FC7-4285-B068-B3F69A2B20E5}         NaN
# 236       237    31830  {C5E33CA9-6048-4AC5-8C2E-24D558A85EF5}         NaN
# 237       238    31816  {073A3071-9E25-4C76-B996-0B448EA09E14}         NaN
# 238       239    30083  {DAFE42D1-C7E2-402F-B894-B2E1E5199A62}         NaN
# 239       240    30293  {70C70932-1A23-4D35-8D37-C55A7A2C65DC}         NaN
#
#                                               geometry  total_crime
# 0    POLYGON ((-84.30229 34.57842, -84.30208 34.578...          NaN
# 1    POLYGON ((-83.64686 34.47594, -83.64749 34.475...          NaN
# 2    POLYGON ((-84.36438 34.41673, -84.36513 34.414...          NaN
# 3    POLYGON ((-83.88020 34.32201, -83.87727 34.325...          NaN
# 4    POLYGON ((-83.70880 34.30056, -83.70693 34.301...          NaN
# ..                                                 ...          ...
# 235  POLYGON ((-83.81487 33.13200, -83.81535 33.131...          NaN
# 236  POLYGON ((-84.76387 32.95170, -84.76570 32.941...          NaN
# 237  POLYGON ((-84.62230 32.92431, -84.62316 32.922...          NaN
# 238  POLYGON ((-84.19451 33.83505, -84.19327 33.834...          NaN
# 239  POLYGON ((-84.71612 32.90012, -84.71393 32.906...          NaN
#
# [240 rows x 6 columns]

# %%
data_new= data.drop('last_edite', axis=1)
data_new

data = data_new.dropna(how="any")
data = data.reset_index()

# %%
import matplotlib.pyplot as plt

# %%
#atlanta area : data.plot(column="total_crime",cmap='OrRd', legend=True, missing_kwds={'color': 'lightgrey'})
data.plot(column="total_crime",cmap='OrRd', legend=True)
atl_city_zip_shp.plot()
#data['coords'] = data['geometry'].apply(lambda x: x.representative_point().coords[:])
#data['coords'] = [coords[0] for coords in data['coords']]


#for i in range(0, data.shape[0]):
#    plt.annotate(data["zipcode"][i], xy=(data['coords'][i][0],data['coords'][i][1]), horizontalalignment='center')
#plt.title("number of crime happened in 2022 within city of Atlanta ")

newplot= data.overlay(atl_city_zip_shp, how="intersection")
newplot.plot(column="total_crime",cmap='OrRd', legend=True)
plt.title("number of crime happened in 2022 within city of Atlanta ")
# Out:
# Text(0.5, 1.0, 'number of crime happened in 2022 within city of Atlanta ')
