# %%
import pandas as pd

# read in the CSV file using pandas
df1 = pd.read_csv("data/atlanta_zip_codes.csv")

# view the first few rows of the dataframe
df1
# Out:
#       zip
# 0   30002
# 1   30030
# 2   30032
# 3   30033
# 4   30067
# 5   30079
# 6   30080
# 7   30084
# 8   30303
# 9   30305
# 10  30306
# 11  30307
# 12  30308
# 13  30309
# 14  30310
# 15  30311
# 16  30312
# 17  30313
# 18  30314
# 19  30315
# 20  30316
# 21  30317
# 22  30318
# 23  30319
# 24  30324
# 25  30326
# 26  30327
# 27  30328
# 28  30329
# 29  30337
# 30  30338
# 31  30339
# 32  30340
# 33  30341
# 34  30342
# 35  30344
# 36  30345
# 37  30346
# 38  30354
# 39  30360
# 40  30363

# %%
print(df1.head(50))
# Out:
#       zip
# 0   30002
# 1   30030
# 2   30032
# 3   30033
# 4   30067
# 5   30079
# 6   30080
# 7   30084
# 8   30303
# 9   30305
# 10  30306
# 11  30307
# 12  30308
# 13  30309
# 14  30310
# 15  30311
# 16  30312
# 17  30313
# 18  30314
# 19  30315
# 20  30316
# 21  30317
# 22  30318
# 23  30319
# 24  30324
# 25  30326
# 26  30327
# 27  30328
# 28  30329
# 29  30337
# 30  30338
# 31  30339
# 32  30340
# 33  30341
# 34  30342
# 35  30344
# 36  30345
# 37  30346
# 38  30354
# 39  30360
# 40  30363

# %%
df1.shape
# Out:
# (41, 1)

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   zip     41 non-null     int64
# dtypes: int64(1)
# memory usage: 456.0 bytes

# %%
for index, row in df1.iterrows():
    print(row)
# Out:
# zip    30002
# Name: 0, dtype: int64
# zip    30030
# Name: 1, dtype: int64
# zip    30032
# Name: 2, dtype: int64
# zip    30033
# Name: 3, dtype: int64
# zip    30067
# Name: 4, dtype: int64
# zip    30079
# Name: 5, dtype: int64
# zip    30080
# Name: 6, dtype: int64
# zip    30084
# Name: 7, dtype: int64
# zip    30303
# Name: 8, dtype: int64
# zip    30305
# Name: 9, dtype: int64
# zip    30306
# Name: 10, dtype: int64
# zip    30307
# Name: 11, dtype: int64
# zip    30308
# Name: 12, dtype: int64
# zip    30309
# Name: 13, dtype: int64
# zip    30310
# Name: 14, dtype: int64
# zip    30311
# Name: 15, dtype: int64
# zip    30312
# Name: 16, dtype: int64
# zip    30313
# Name: 17, dtype: int64
# zip    30314
# Name: 18, dtype: int64
# zip    30315
# Name: 19, dtype: int64
# zip    30316
# Name: 20, dtype: int64
# zip    30317
# Name: 21, dtype: int64
# zip    30318
# Name: 22, dtype: int64
# zip    30319
# Name: 23, dtype: int64
# zip    30324
# Name: 24, dtype: int64
# ...

# %%
# read in the CSV file using pandas
df2 = pd.read_csv("data/Zip_zhvi_uc_sfr_tier_0.33_0.67_sm_sa_month.csv")

# view the first few rows of the dataframe
df2
# Out:
#      RegionID  SizeRank  RegionName RegionType StateName State         City  \
# 0     70878.0     495.0     30101.0        zip        GA    GA      Acworth
# 1     70879.0    1741.0     30102.0        zip        GA    GA      Acworth
# 2     70880.0    7163.0     30103.0        zip        GA    GA  Adairsville
# 3     70792.0    1903.0     30005.0        zip        GA    GA   Alpharetta
# 4     70796.0    6623.0     30009.0        zip        GA    GA   Alpharetta
# ..        ...       ...         ...        ...       ...   ...          ...
# 196   70950.0    8922.0     30184.0        zip        GA    GA          NaN
# 197   70963.0    9565.0     30217.0        zip        GA    GA          NaN
# 198   70948.0   15254.0     30182.0        zip        GA    GA          NaN
# 199   70939.0   15395.0     30171.0        zip        GA    GA          NaN
# 200   70938.0   16325.0     30170.0        zip        GA    GA          NaN
#
# ...

# %%
print(df2.head())
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State         City  \
# 0   70878.0     495.0     30101.0        zip        GA    GA      Acworth
# 1   70879.0    1741.0     30102.0        zip        GA    GA      Acworth
# 2   70880.0    7163.0     30103.0        zip        GA    GA  Adairsville
# 3   70792.0    1903.0     30005.0        zip        GA    GA   Alpharetta
# 4   70796.0    6623.0     30009.0        zip        GA    GA   Alpharetta
#
#                                   Metro       CountyName  1/31/2000  \
# 0  Atlanta-Sandy Springs-Alpharetta, GA      Cobb County   181793.0
# 1  Atlanta-Sandy Springs-Alpharetta, GA  Cherokee County   147639.0
# 2  Atlanta-Sandy Springs-Alpharetta, GA    Bartow County    83056.0
# 3  Atlanta-Sandy Springs-Alpharetta, GA    Fulton County   271314.0
# 4  Atlanta-Sandy Springs-Alpharetta, GA    Fulton County   227013.0
#
#    2/29/2000  3/31/2000  4/30/2000  5/31/2000  6/30/2000  7/31/2000  \
# ...

# %%
df2.shape
# Out:
# (201, 285)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Columns: 285 entries, RegionID to 12/31/2022
# dtypes: float64(279), object(6)
# memory usage: 447.7+ KB

# %%
# iterate through each row of the dataframe
for index, row in df2.iterrows():
    print(row)
# Out:
# RegionID       70878.0
# SizeRank         495.0
# RegionName     30101.0
# RegionType         zip
# StateName           GA
#                 ...
# 8/31/2022     438960.0
# 9/30/2022     438542.0
# 10/31/2022    437779.0
# 11/30/2022    438268.0
# 12/31/2022    437313.0
# Name: 0, Length: 285, dtype: object
# RegionID       70879.0
# SizeRank        1741.0
# RegionName     30102.0
# RegionType         zip
# StateName           GA
#                 ...
# 8/31/2022     377550.0
# 9/30/2022     378488.0
# 10/31/2022    377565.0
# 11/30/2022    377004.0
# 12/31/2022    375624.0
# Name: 1, Length: 285, dtype: object
# RegionID       70880.0
# SizeRank        7163.0
# RegionName     30103.0
# RegionType         zip
# StateName           GA
#                 ...
# 8/31/2022     276185.0
# 9/30/2022     278774.0
# 10/31/2022    281114.0
# 11/30/2022    282722.0
# 12/31/2022    283763.0
# Name: 2, Length: 285, dtype: object
# RegionID       70792.0
# SizeRank        1903.0
# ...

# %%
# count rows
df2.columns
# Out:
# <bound method Index.all of Index(['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
#        'State', 'City', 'Metro', 'CountyName', '1/31/2000',
#        ...
#        '3/31/2022', '4/30/2022', '5/31/2022', '6/30/2022', '7/31/2022',
#        '8/31/2022', '9/30/2022', '10/31/2022', '11/30/2022', '12/31/2022'],
#       dtype='object', length=285)>

# %%
# use code from Activites to print rows

# %%
df2[['RegionName','1/31/2022','2/28/2022','3/31/2022','4/30/2022','5/31/2022','6/30/2022','7/31/2022','8/31/2022','9/30/2022','10/31/2022','11/30/2022','12/31/2022']]
# Out:
#      RegionName  1/31/2022  2/28/2022  3/31/2022  4/30/2022  5/31/2022  \
# 0       30101.0   394262.0   402691.0   413677.0   422604.0   430893.0
# 1       30102.0   339024.0   346569.0   354793.0   362075.0   367607.0
# 2       30103.0   241944.0   246990.0   251456.0   256172.0   261579.0
# 3       30005.0   631851.0   648160.0   661735.0   678134.0   694597.0
# 4       30009.0   590272.0   604980.0   615806.0   629494.0   643785.0
# ..          ...        ...        ...        ...        ...        ...
# 196     30184.0   340251.0   347157.0   354109.0   360271.0   366142.0
# 197     30217.0   182801.0   187964.0   190033.0   192460.0   193748.0
# 198     30182.0   208848.0   215045.0   219540.0   224132.0   228050.0
# 199     30171.0   305933.0   310420.0   315972.0   320939.0   326741.0
